# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns = df.columns.str.lower()

# %%
df1 = pd.concat([pd.get_dummies(df.sex), pd.get_dummies(df.embarked)], axis=1)

# %%
a = pd.concat([df, df1], axis=1)
a.drop(['name', 'sex', 'ticket', 'cabin'], axis=1, inplace=True)

# %%
a.drop('embarked', axis=1, inplace=True)

# %%
a.head()
# Out:
#    passengerid  survived  pclass   age  sibsp  parch     fare  female  male  \
# 0            1         0       3  22.0      1      0   7.2500       0     1
# 1            2         1       1  38.0      1      0  71.2833       1     0
# 2            3         1       3  26.0      0      0   7.9250       1     0
# 3            4         1       1  35.0      1      0  53.1000       1     0
# 4            5         0       3  35.0      0      0   8.0500       0     1
#
#    C  Q  S
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  0  1

# %%
a.drop(['passengerid', 'survived'], axis=1, inplace=True)
a.head()
# Out:
#    pclass   age  sibsp  parch     fare  female  male  C  Q  S
# 0       3  22.0      1      0   7.2500       0     1  0  0  1
# 1       1  38.0      1      0  71.2833       1     0  1  0  0
# 2       3  26.0      0      0   7.9250       1     0  0  0  1
# 3       1  35.0      1      0  53.1000       1     0  0  0  1
# 4       3  35.0      0      0   8.0500       0     1  0  0  1

# %%
b = a.drop('female', axis=1)
b.head()
# Out:
#    pclass   age  sibsp  parch     fare  male  C  Q  S
# 0       3  22.0      1      0   7.2500     1  0  0  1
# 1       1  38.0      1      0  71.2833     0  1  0  0
# 2       3  26.0      0      0   7.9250     0  0  0  1
# 3       1  35.0      1      0  53.1000     0  0  0  1
# 4       3  35.0      0      0   8.0500     1  0  0  1

# %%
b.dropna(inplace=True)
b.shape
# Out:
# (714, 9)

# %%
import statsmodels.api as sm

# %%
def calculate_vif(data):
    vif_df = pd.DataFrame(columns = ['Var', 'Vif'])
    x_var_names = data.columns
    for i in range(0, x_var_names.shape[0]):
        y = data[x_var_names[i]]
        x = data[x_var_names.drop([x_var_names[i]])]
        #print(x.columns)
        #print(x_var_names[i])
        r_squared = sm.OLS(y,x).fit().rsquared
        #print(i)
        #print(r_squared)
        vif = round(1/(1-r_squared),2)
        vif_df.loc[i] = [x_var_names[i], vif]
    return vif_df.sort_values(by = 'Vif', axis = 0, ascending=False, inplace=False)

# %%
a.dropna(inplace=True)
a.shape
# Out:
# (714, 10)

# %%
calculate_vif(a)
# Out:
#       Var     Vif
# 6    male  108.99
# 9       S   63.33
# 7       C   54.54
# 8       Q   14.68
# 5  female    2.71
# 0  pclass    1.80
# 4    fare    1.65
# 1     age    1.32
# 3   parch    1.29
# 2   sibsp    1.28

# %%
a.drop('pclass', axis=1, inplace=True)

# %%
calculate_vif(a)
# Out:
#       Var   Vif
# 0     age  5.78
# 5       C  2.35
# 3    fare  1.74
# 1   sibsp  1.67
# 2   parch  1.60
# 6       Q  1.26
# 7       S  0.44
# 4  female  0.03
