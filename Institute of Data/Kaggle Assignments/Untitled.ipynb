# %%
import pandas as pd
import numpy as np

# %%
url = 'https://data.gov.au/data/storage/f/2013-05-12T201722/tmprWYF4_Average_electricity_consumption_by_LGA-rev-6Apr11.ashx'
df = pd.read_csv(url)
df.head(20)
# Out:
#                        Unnamed: 0 Residential Total Unnamed: 2 Unnamed: 3  \
# 0    Local Government Area (LGA)                kWh  Customers   kWh/cust
# 1                       ASHFIELD         94,116,216     18,254      5,156
# 2                         AUBURN        138,550,435     24,691      5,611
# 3                      BANKSTOWN        465,153,524     63,708      7,301
# 4                     BOTANY BAY         85,691,958     16,099      5,323
# 5                        BURWOOD         75,711,992     12,311      6,150
# 6                     CANADA BAY        197,154,118     32,114      6,139
# 7                     CANTERBURY        310,482,618     53,696      5,782
# 8                       CESSNOCK        165,348,966     20,667      8,001
# 9                        GOSFORD        540,823,517     75,782      7,137
# 10                       HORNSBY        465,675,067     55,808      8,344
# 11                  HUNTERS HILL         48,274,706      5,218      9,252
# ...

# %%
df.shape
# Out:
# (48, 16)
